# %%
import pandas as pd
df = pd.read_csv('../data/student_performance_analysis.csv')
df.head()

# %%
df.describe()

# %% [markdown]
# ### Visualisasi Distribusi Fitur

# %%
# Visualisasi distribusi setiap fitur numerik
import matplotlib.pyplot as plt
df.hist(figsize=(12,8))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Korelasi Antar Fitur

# %%
# Korelasi antar fitur
import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Matriks Korelasi')
plt.show()

# %% [markdown]
# ### Analisis Missing Value

# %%
# Analisis missing value
missing = df.isnull().sum()
missing[missing > 0]

# %% [markdown]
# ## Catatan Eksplorasi
# - Lihat distribusi data dan outlier pada histogram.
# - Perhatikan fitur yang memiliki korelasi tinggi.
# - Cek apakah ada missing value yang perlu ditangani sebelum training.
